# %%
# Install required packages
# %pip install opencv-python deepface
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: deepface in ./.venv/lib/python3.10/site-packages (0.0.93)
# Requirement already satisfied: numpy>=1.17.3 in ./.venv/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: requests>=2.27.1 in ./.venv/lib/python3.10/site-packages (from deepface) (2.32.3)
# Requirement already satisfied: tensorflow>=1.9.0 in ./.venv/lib/python3.10/site-packages (from deepface) (2.16.2)
# Requirement already satisfied: keras>=2.2.0 in ./.venv/lib/python3.10/site-packages (from deepface) (3.9.1)
# Requirement already satisfied: gdown>=3.10.1 in ./.venv/lib/python3.10/site-packages (from deepface) (5.2.0)
# Requirement already satisfied: pandas>=0.23.4 in ./.venv/lib/python3.10/site-packages (from deepface) (2.2.3)
# Requirement already satisfied: mtcnn>=0.1.0 in ./.venv/lib/python3.10/site-packages (from deepface) (1.0.0)
# Requirement already satisfied: flask-cors>=4.0.1 in ./.venv/lib/python3.10/site-packages (from deepface) (5.0.1)
# Requirement already satisfied: fire>=0.4.0 in ./.venv/lib/python3.10/site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in ./.venv/lib/python3.10/site-packages (from deepface) (23.0.0)
# Requirement already satisfied: tqdm>=4.30.0 in ./.venv/lib/python3.10/site-packages (from deepface) (4.67.1)
# Requirement already satisfied: Flask>=1.1.2 in ./.venv/lib/python3.10/site-packages (from deepface) (3.1.0)
# Requirement already satisfied: Pillow>=5.2.0 in ./.venv/lib/python3.10/site-packages (from deepface) (11.1.0)
# Requirement already satisfied: retina-face>=0.0.1 in ./.venv/lib/python3.10/site-packages (from deepface) (0.0.17)
# Requirement already satisfied: termcolor in ./.venv/lib/python3.10/site-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: blinker>=1.9 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: Werkzeug>=3.1 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: click>=8.1.3 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: itsdangerous>=2.2 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (4.13.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Requirement already satisfied: h5py in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (3.13.0)
# Requirement already satisfied: namex in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: rich in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (13.9.4)
# Requirement already satisfied: ml-dtypes in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.3.2)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (2.2.1)
# Requirement already satisfied: optree in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.14.1)
# Requirement already satisfied: lz4>=4.3.3 in ./.venv/lib/python3.10/site-packages (from mtcnn>=0.1.0->deepface) (4.4.3)
# Requirement already satisfied: joblib>=1.4.2 in ./.venv/lib/python3.10/site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (2.3.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.25.6)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.71.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (65.5.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=1.9.0->deepface) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (1.7.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=2.2.0->deepface) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import cv2

# This function captures a photo using the webcam and saves it to a specified filename.
# It allows the user to take a photo by pressing 's' and quit without saving by pressing 'q'.
def take_photo(filename='photo.jpg'):
    """
    Opens the webcam, lets the user take a photo by pressing 's', and saves it.
    Press 'q' to quit without saving.
    """
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Cannot open webcam")
        return None

    print("Webcam is live. Press 's' to save photo or 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame")
            break

        cv2.imshow('Live Feed - Press s to Save or q to Quit', frame)
        key = cv2.waitKey(1)

        if key == ord('s'):
            cv2.imwrite(filename, frame)
            print(f"Photo saved as '{filename}'")
            break
        elif key == ord('q'):
            print("Quit without saving")
            break

    cap.release()
    cv2.destroyAllWindows()
    return filename

# %%
# Install additional required packages
# %pip install deepface
# %pip install tf-keras
# Out:
# Requirement already satisfied: deepface in ./.venv/lib/python3.10/site-packages (0.0.93)
# Requirement already satisfied: tensorflow>=1.9.0 in ./.venv/lib/python3.10/site-packages (from deepface) (2.16.2)
# Requirement already satisfied: Pillow>=5.2.0 in ./.venv/lib/python3.10/site-packages (from deepface) (11.1.0)
# Requirement already satisfied: flask-cors>=4.0.1 in ./.venv/lib/python3.10/site-packages (from deepface) (5.0.1)
# Requirement already satisfied: gdown>=3.10.1 in ./.venv/lib/python3.10/site-packages (from deepface) (5.2.0)
# Requirement already satisfied: requests>=2.27.1 in ./.venv/lib/python3.10/site-packages (from deepface) (2.32.3)
# Requirement already satisfied: mtcnn>=0.1.0 in ./.venv/lib/python3.10/site-packages (from deepface) (1.0.0)
# Requirement already satisfied: fire>=0.4.0 in ./.venv/lib/python3.10/site-packages (from deepface) (0.7.0)
# Requirement already satisfied: numpy>=1.14.0 in ./.venv/lib/python3.10/site-packages (from deepface) (1.26.4)
# Requirement already satisfied: keras>=2.2.0 in ./.venv/lib/python3.10/site-packages (from deepface) (3.9.1)
# Requirement already satisfied: pandas>=0.23.4 in ./.venv/lib/python3.10/site-packages (from deepface) (2.2.3)
# Requirement already satisfied: tqdm>=4.30.0 in ./.venv/lib/python3.10/site-packages (from deepface) (4.67.1)
# Requirement already satisfied: gunicorn>=20.1.0 in ./.venv/lib/python3.10/site-packages (from deepface) (23.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in ./.venv/lib/python3.10/site-packages (from deepface) (0.0.17)
# Requirement already satisfied: Flask>=1.1.2 in ./.venv/lib/python3.10/site-packages (from deepface) (3.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in ./.venv/lib/python3.10/site-packages (from deepface) (4.11.0.86)
# Requirement already satisfied: termcolor in ./.venv/lib/python3.10/site-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=3.1 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in ./.venv/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (4.13.3)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Requirement already satisfied: ml-dtypes in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.3.2)
# Requirement already satisfied: rich in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (13.9.4)
# Requirement already satisfied: optree in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.14.1)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (2.2.1)
# Requirement already satisfied: namex in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in ./.venv/lib/python3.10/site-packages (from keras>=2.2.0->deepface) (3.13.0)
# Requirement already satisfied: lz4>=4.3.3 in ./.venv/lib/python3.10/site-packages (from mtcnn>=0.1.0->deepface) (4.4.3)
# Requirement already satisfied: joblib>=1.4.2 in ./.venv/lib/python3.10/site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (3.4.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (2.16.2)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.71.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.25.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.13.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=1.9.0->deepface) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.venv/lib/python3.10/site-packages (from requests>=2.27.1->deepface) (1.7.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=2.2.0->deepface) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tf-keras in ./.venv/lib/python3.10/site-packages (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in ./.venv/lib/python3.10/site-packages (from tf-keras) (2.16.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.16.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (24.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (4.13.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.13.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.71.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.5.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.17.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.32.3)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.2.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (65.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.17.2)
# Requirement already satisfied: ml-dtypes~=0.3.1 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.3.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.37.1)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (25.2.10)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (4.25.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.4.0)
# Requirement already satisfied: keras>=3.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.26.4)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.6.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (18.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.10/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tf-keras) (0.45.1)
# Requirement already satisfied: rich in ./.venv/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (13.9.4)
# Requirement already satisfied: optree in ./.venv/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.14.1)
# Requirement already satisfied: namex in ./.venv/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.0.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (2.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries for image comparison
import os
from deepface import DeepFace

# This function compares a local photo (taken from webcam) with an image from a URL using DeepFace.
# It prints whether the faces belong to the same person or not.
def compare_photo_with_url(local_image_path, image_url):
    """
    Compares a local photo (taken from webcam) with an image from a URL using DeepFace.
    Prints whether it's the same person or not.
    """
    try:
        print(f"\nComparing '{local_image_path}' with image from URL...")
        result = DeepFace.verify(
            img1_path=local_image_path,
            img2_path=image_url,
            model_name='Facenet',          
            detector_backend='opencv',     
            enforce_detection=True
        )
        if result["verified"]:
            print("Match: The face matches known people.")
            return True
        else:
            print("No match: The face doesn't match known people.")
            return False
    except Exception as e:
        print(f"Error during comparison: {e}")
        return False
# Out:
# 2025-03-29 17:06:26.349686: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
'''
# Step 1: Take photo
photo_path = take_photo()

# Step 2: Provide your image URL from the database (Supabase or similar)

# Iterate through an array of image URLs, and if it matches the photo from the webcam, return true

image_url = "https://drive.usercontent.google.com/download?id=15xSUXA0Xsr4RIlM377ibu_XX19BrPe1E&authuser=0"

# Step 3: Compare webcam photo with the image from the URL
if photo_path and os.path.exists(photo_path):
    compare_photo_with_url(photo_path, image_url)
else:
    print("No photo was taken or saved.")'
'
'''
# Out:
# Webcam is live. Press 's' to save photo or 'q' to quit.
# Photo saved as 'photo.jpg'
#
# Comparing 'photo.jpg' with image from URL...
# Match: The face matches known people.

# %%
'''
database_urls = [
    "https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/0bbf046b-21cc-43e9-8994-1231ed37ea20.jpg",
    "https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/479e3019-f6fd-4e0e-a12d-c38fc689d953.jpg",
    "https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/4e074e26-86d2-479d-92f3-25be071bfd25.jpg"]'
'''


def compare_photo_and_array(photo_path, Database_URLS):
    """
    Compares a local photo with images from an array of URLs using DeepFace.
    Prints whether any of the faces belong to the same person or not.
    """
    for image_url in Database_URLS:
        print(f"Comparing with: {image_url}")
        try:
            result = compare_photo_with_url(photo_path, image_url)
            if result:  # Assuming compare_photo_with_url returns True if a match is found
                print(f"Match found with: {image_url}")
                return True
        except Exception as e:
            print(f"Error comparing with {image_url}: {str(e)}")
    return False


# Step 1: Take photo
photo_path = take_photo()

# Step 2: Use the compare_photo_and_array function to compare the photo with the array of URLs
if photo_path and os.path.exists(photo_path):
    match_found = compare_photo_and_array(photo_path, Database_URLS)
    if match_found:
        print("Match found in the array of URLs.")
    else:
        print("No match found in the array of URLs.")
else:
    print("No photo was taken or saved.")
# Out:
# Webcam is live. Press 's' to save photo or 'q' to quit.
# Photo saved as 'photo.jpg'
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/daaf74d2-d950-41b0-9445-05141b4e5818.jpg
#
# Comparing 'photo.jpg' with image from URL...
# No match: The face doesn't match known people.
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/36701b4e-d4a0-4189-8c5a-237872d44b5c.jpg
#
# Comparing 'photo.jpg' with image from URL...
# Error during comparison: Exception while processing img2_path
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/f41b08df-8b49-4cd5-96ab-f0a6f6238e2f.jpg
#
# Comparing 'photo.jpg' with image from URL...
# No match: The face doesn't match known people.
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/61f49475-76c4-4046-958c-84333bd3186d.jpg
#
# Comparing 'photo.jpg' with image from URL...
# No match: The face doesn't match known people.
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/4c91b2aa-0b20-4afb-afdd-5a3f1b574019.jpg
#
# Comparing 'photo.jpg' with image from URL...
# Error during comparison: Exception while processing img2_path
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/093bb380-4bda-4b2f-8c82-3bf2e936e6d6.jpg
#
# Comparing 'photo.jpg' with image from URL...
# No match: The face doesn't match known people.
# Comparing with: https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/5157ec4b-c164-48ca-b31c-cdf66601bbae.jpg
#
# Comparing 'photo.jpg' with image from URL...
# No match: The face doesn't match known people.
# No match found in the array of URLs.
