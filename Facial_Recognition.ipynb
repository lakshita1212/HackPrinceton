# %%
# %pip install opencv-python
import cv2

def take_photo(filename='photo.jpg'):
    # Start webcam
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Cannot open webcam")
        return None

    print("Webcam is running. Press 's' to save photo or 'q' to quit.")

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame")
            break

        # Display the resulting frame
        cv2.imshow('Live Feed - Press s to Save or q to Quit', frame)

        key = cv2.waitKey(1)

        if key == ord('s'):  # Press 's' to save photo
            cv2.imwrite(filename, frame)
            print(f"Photo saved as {filename}")
            cv2.destroyAllWindows()  # Close the camera window
            break
        elif key == ord('q'):  # Press 'q' to quit without saving
            print("Quit without saving")
            cv2.destroyAllWindows()  # Close the camera window
            break

    # When everything is done, release the capture
    cap.release()
    return filename


# Run the capture function
try:
    filename = take_photo()
    if filename and os.path.exists(filename):
        print(f"Saved to {filename}")
        import os
        os.system(f"open {filename}")  # Mac image viewer
    else:
        print("No photo was saved.")
except Exception as e:
    print("Error:", e)

# %%
# %pip install opencv-python
import cv2

def take_photo(filename='photo.jpg'):
    # Start webcam
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Cannot open webcam")
        return None

    print("Webcam is running. Press 's' to save photo or 'q' to quit.")

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame")
            break

        # Display the resulting frame
        cv2.imshow('Live Feed - Press s to Save or q to Quit', frame)

        key = cv2.waitKey(1)

        if key == ord('s'):  # Press 's' to save photo
            cv2.imwrite(filename, frame)
            print(f"Photo saved as {filename}")
            cv2.destroyAllWindows()  # Close the camera window
            break
        elif key == ord('q'):  # Press 'q' to quit without saving
            print("Quit without saving")
            cv2.destroyAllWindows()  # Close the camera window
            break

    # When everything is done, release the capture
    cap.release()
    return filename


# Run the capture function
try:
    filename = take_photo()
    if filename and os.path.exists(filename):
        print(f"Saved to {filename}")
        import os
        os.system(f"open {filename}")  # Mac image viewer
    else:
        print("No photo was saved.")
except Exception as e:
    print("Error:", e)
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.10/site-packages (from opencv-python) (2.2.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Webcam is running. Press 's' to save photo or 'q' to quit.
# Quit without saving
# Error: name 'os' is not defined

# %%
# Takes two images and compares the faces, if the images have the same faces then it 
# returns that it is a match, if its different faces then it returns that it is not a match

# %pip install opencv-python
import cv2

def compare_faces(image1_path, image2_path):
    # Load the images
    image1 = cv2.imread(image1_path)
    image2 = cv2.imread(image2_path)

    # Convert the images to grayscale
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

    # Initialize the face detector
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Detect faces in the first image
    faces1 = face_cascade.detectMultiScale(gray1, scaleFactor=1.1, minNeighbors=5)
    faces2 = face_cascade.detectMultiScale(gray2, scaleFactor=1.1, minNeighbors=5)

    if len(faces1) == 0 or len(faces2) == 0:
        print("No faces found in one or both images.")
        return False

    # Compare the first detected face in each image
    (x1, y1, w1, h1) = faces1[0]
    (x2, y2, w2, h2) = faces2[0]

    face1 = gray1[y1:y1+h1, x1:x1+w1]
    face2 = gray2[y2:y2+h2, x2:x2+w2]

    # Resize the faces to the same size for comparison
    face1_resized = cv2.resize(face1, (w1, h1))
    face2_resized = cv2.resize(face2, (w1, h1))

    # Calculate the difference between the two faces
    difference = cv2.absdiff(face1_resized, face2_resized)
    
    # Convert to grayscale and threshold
    _, thresh = cv2.threshold(difference, 30, 255, cv2.THRESH_BINARY)

    # Count non-zero pixels in the thresholded image
    non_zero_count = cv2.countNonZero(thresh)

    # If the number of different pixels is small enough, consider it a match
    if non_zero_count < 1000:  # Adjust this threshold as needed
        print("The faces match!")
        return True
    else:
        print("The faces do not match.")
        return False
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.19.3 in ./.venv/lib/python3.10/site-packages (from opencv-python) (2.2.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import face_recognition

def compare_faces(img1_path, img2_path):
    # Load the images
    image1 = face_recognition.load_image_file(img1_path)
    image2 = face_recognition.load_image_file(img2_path)

    # Get face encodings
    encoding1 = face_recognition.face_encodings(image1)
    encoding2 = face_recognition.face_encodings(image2)

    if not encoding1:
        print(f"No face found in {img1_path}")
        return
    if not encoding2:
        print(f"No face found in {img2_path}")
        return

    # Compare faces
    match = face_recognition.compare_faces([encoding1[0]], encoding2[0], tolerance=0.6)

    if match[0]:
        print("Match: Same person")
    else:
        print("No match: Different people")

# %%
compare_faces("known_faces/person1.png", "known_faces/test.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 compare_faces("known_faces/person1.png", "known_faces/test.png")
#
# Cell In[11], line 5, in compare_faces(img1_path, img2_path)
#       3 def compare_faces(img1_path, img2_path):
#       4     # Load the images
# ----> 5     image1 = face_recognition.load_image_file(img1_path)
#       6     image2 = face_recognition.load_image_file(img2_path)
#       8     # Get face encodings
#
# File ~/Documents/PrincetonHack/.venv/lib/python3.10/site-packages/face_recognition/api.py:86, in load_image_file(file, mode)
#      78 def load_image_file(file, mode='RGB'):
#      79     """
#      80     Loads an image file (.jpg, .png, etc) into a numpy array
#      81
#    (...)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# File ~/Documents/PrincetonHack/.venv/lib/python3.10/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'known_faces/person1.png'

# %%
from PIL import Image
from IPython.display import display

img1 = Image.open("known_faces/person1.jpg")
img2 = Image.open("known_faces/test.jpg")

print("Known Image:")
display(img1)

print("Test Image:")
display(img2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from PIL import Image
#       2 from IPython.display import display
# ----> 4 img1 = Image.open("known_faces/person1.jpg")
#       5 img2 = Image.open("known_faces/test.jpg")
#       7 print("Known Image:")
#
# File ~/Documents/PrincetonHack/.venv/lib/python3.10/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'known_faces/person1.jpg'

# %%
# %pip install requests
# %pip install requests pillow face-recognition
# Out:
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests) (3.10)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: pillow in ./.venv/lib/python3.10/site-packages (11.1.0)
# Requirement already satisfied: face-recognition in ./.venv/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from face-recognition) (2.2.4)
# Requirement already satisfied: Click>=6.0 in ./.venv/lib/python3.10/site-packages (from face-recognition) (8.1.8)
# Requirement already satisfied: dlib>=19.7 in ./.venv/lib/python3.10/site-packages (from face-recognition) (19.24.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in ./.venv/lib/python3.10/site-packages (from face-recognition) (0.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import face_recognition
from io import BytesIO
import numpy as np
from PIL import Image

def compare_faces_from_urls(url1, url2):
    try:
        def load_image_from_url(url):
            response = requests.get(url, timeout=10)
            response.raise_for_status()

            # Open with PIL and enforce RGB
            img = Image.open(BytesIO(response.content)).convert('RGB')

            # Convert to C-contiguous NumPy array
            img_array = np.array(img, dtype=np.uint8)
            img_array = np.ascontiguousarray(img_array)

            return img_array

        # Load both images (Replaced)
        image1 = np.ascontiguousarray(load_image_from_url(url1))
        image2 = np.ascontiguousarray(load_image_from_url(url2))

        # Validate array properties
        for i, img in enumerate([image1, image2], 1):
            print(f"Image {i} properties:")
            print(f"- Shape: {img.shape}")
            print(f"- Dtype: {img.dtype}")
            print(f"- Min value: {img.min()}")
            print(f"- Max value: {img.max()}")
            print(f"- Mode: {'RGB' if img.shape[2] == 3 else 'Grayscale'}")



        from face_recognition.api import face_encodings

        # Force array to be proper C-contiguous uint8
        image1 = np.array(image1, dtype=np.uint8, copy=True, order='C')
        image2 = np.array(image2, dtype=np.uint8, copy=True, order='C')

        # Debug: Print memory layout flags
        print("Image 1 flags:", image1.flags)
        print("Image 2 flags:", image2.flags)

        # Encode the faces using the lower-level face_recognition.api
        encodings1 = face_encodings(image1)
        encodings2 = face_encodings(image2)

        # Debug: Print encoding shapes
        print("Encodings 1 shape:", encodings1[0].shape if len(encodings1) > 0 else "No faces detected")
        print("Encodings 2 shape:", encodings2[0].shape if len(encodings2) > 0 else "No faces detected")
        # Check if any faces were detected
        print("Encodings 1 count:", len(encodings1))
        print("Encodings 2 count:", len(encodings2))




        if len(encodings1) == 0 or len(encodings2) == 0:
            print("No faces detected in one or both images.")
            return False

        # Compare the first face in each image
        match = face_recognition.compare_faces([encodings1[0]], encodings2[0])

        if match[0]:
            print("The faces match!")
            return True
        else:
            print("The faces do not match.")
            return False

    except Exception as e:
        print(f"Error: {e}")
        return False

# %%
compare_faces_from_urls(
    "https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/daaf74d2-d950-41b0-9445-05141b4e5818.jpg",
    "https://ooiszpalwebsurwuuvjn.supabase.co/storage/v1/object/public/patient-images/patient-images/daaf74d2-d950-41b0-9445-05141b4e5818.jpg"
)
# Out:
# Image 1 properties:
# - Shape: (500, 896, 3)
# - Dtype: uint8
# - Min value: 0
# - Max value: 255
# - Mode: RGB
# Image 2 properties:
# - Shape: (500, 896, 3)
# - Dtype: uint8
# - Min value: 0
# - Max value: 255
# - Mode: RGB
# Image 1 flags:   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#
# Image 2 flags:   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#
# Error: Unsupported image type, must be 8bit gray or RGB image.
# False
